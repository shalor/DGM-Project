# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd "/content/drive/My Drive/DGM/NICE_3/NICE-master"
# Out:
# /content/drive/My Drive/DGM/NICE_3/NICE-master

# %%
# !ls
# Out:
# LICENSE  nice.py      README.md       samples	  train.py  zca.py
# models	 __pycache__  reconstruction  statistics  utils.py

# %%
# !python nice.py

# %%
# !python utils.py

# %%
# !python zca.py
# Out:
# Traceback (most recent call last):
#   File "zca.py", line 25, in <module>
#     root='../../data', transform=torchvision.transforms.ToTensor())
#   File "/usr/local/lib/python3.7/dist-packages/torchvision/datasets/cifar.py", line 69, in __init__
#     raise RuntimeError('Dataset not found or corrupted.' +
# RuntimeError: Dataset not found or corrupted. You can use download=True to download it

# %%
# !python train.py
# Out:
# ...
# 170499072it [00:02, 63555814.45it/s]
# Extracting /root/torch/data/CIFAR10/cifar-10-python.tar.gz to /root/torch/data/CIFAR10
# /usr/local/lib/python3.7/dist-packages/torch/distributions/distribution.py:46: UserWarning: <class 'utils.StandardLogistic'> does not define `arg_constraints`. Please set `arg_constraints = {}` or initialize the distribution with `validate_args=False` to turn off validation.
#   'with `validate_args=False` to turn off validation.')
# iter 1000: loss = 3563.209 bits/dim = 9.673
# iter 2000: loss = 2758.338 bits/dim = 9.295
# iter 3000: loss = 2695.462 bits/dim = 9.266
# iter 4000: loss = 2679.200 bits/dim = 9.258
# iter 5000: loss = 2666.269 bits/dim = 9.252
# iter 6000: loss = 2656.132 bits/dim = 9.247
# iter 7000: loss = 2648.209 bits/dim = 9.244
# iter 8000: loss = 2641.428 bits/dim = 9.240
# iter 9000: loss = 2635.678 bits/dim = 9.238
# iter 10000: loss = 2630.292 bits/dim = 9.235
# iter 11000: loss = 2626.141 bits/dim = 9.233
# ...
